# %% [markdown]
# # Predicting the Price of Bulldozers using Machine Learning

# %% [markdown]
# We are going to use the characteristics of bulldozers and their past sales to predict the price of future bulldozers.
#
#  - inputs: Characteristics such as year made, model, state of stale and more
#  - outputs: The bulldozers' sale price
#
# This is a regression problem since we are predicting numbers.
#
# We will be using numpy, pandas, matplotlib for data analysis and scikit-learn for machine learning and modelling tasks.
#
# ### Problem Definition
#
# > How well can we predict the sale price of bulldozer using its characteristics and how much similar bulldozers have been sold in the past
#
#
# ### Data gathering
# The data is from the kaggle bluebook.
#
# it's historical sales data of bulldozers.Including model type, size, sale date and more.
#
# There are 3 datasets:
#
# * Train.csv - Historical bulldozer sales examples up to 2011 (close to 400,000 examples with 50+ different attributes, including SalePrice, which is the target variable).
# * Valid.csv - Historical bulldozer sales examples from January 1 2012 to April 30 2012 (close to 12,000 examples with the same attributes as Train.csv).
# * Test.csv - Historical bulldozer sales examples from May 1 2012 to November 2012 (close to 12,000 examples but missing the SalePrice attribute, as this is what we'll be trying to predict).
#
# > Note: You can download the dataset bluebook-for-bulldozers dataset directly from Kaggle.
#
# ### Evaluation
#
# The evaluation metric is root mean squared log error (RMSLE) between the actual and predicted actual prices.
#
#  **Note:** As with many regression evaluations, the goal will be to get this value as low as possible.
#
# ### Features
#
# - The features are in the data dictionary provided by Kaggle and contain information about what each attribute of the dataset means.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# Plot to appear inside notebook
# %matplotlib inline

# %%
df = pd.read_csv("./data/bluebook-for-bulldozers/TrainAndValid.csv")
# Out:
# /tmp/ipykernel_844268/142729134.py:1: DtypeWarning: Columns (0: fiModelSeries, 1: Coupler_System, 2: Grouser_Tracks, 3: Hydraulics_Flow) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./data/bluebook-for-bulldozers/TrainAndValid.csv")

# %%
df.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   str
#  9   saledate                  412698 non-null  str
#  10  fiModelDesc               412698 non-null  str
#  11  fiBaseModel               412698 non-null  str
#  12  fiSecondaryDesc           271971 non-null  str
#  13  fiModelSeries             58667 non-null   object
# ...

# %%
 df.saledate.dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df.saledate[:1000]
# Out:
# 0      11/16/2006 0:00
# 1       3/26/2004 0:00
# 2       2/26/2004 0:00
# 3       5/19/2011 0:00
# 4       7/23/2009 0:00
#             ...
# 995     7/16/2009 0:00
# 996     6/14/2007 0:00
# 997     9/22/2005 0:00
# 998     7/28/2005 0:00
# 999     6/16/2011 0:00
# Name: saledate, Length: 1000, dtype: str

# %%
df = pd.read_csv("./data/bluebook-for-bulldozers/TrainAndValid.csv",parse_dates=["saledate"])
# Out:
# /tmp/ipykernel_844268/190891572.py:1: DtypeWarning: Columns (0: fiModelSeries, 1: Coupler_System, 2: Grouser_Tracks, 3: Hydraulics_Flow) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./data/bluebook-for-bulldozers/TrainAndValid.csv",parse_dates=["saledate"])

# %%
df.saledate.dtype
# Out:
# dtype('<M8[us]')

# %%
df.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246    66000.0     999089     3157         121           3.0      2004
# 1  1139248    57000.0     117657       77         121           3.0      1996
# 2  1139249    10000.0     434808     7009         121           3.0      2001
# 3  1139251    38500.0    1026470      332         121           3.0      2001
# 4  1139253    11000.0    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand   saledate  ... Undercarriage_Pad_Width  \
# 0                      68.0       Low 2006-11-16  ...                     NaN
# 1                    4640.0       Low 2004-03-26  ...                     NaN
# 2                    2838.0      High 2004-02-26  ...                     NaN
# 3                    3486.0      High 2011-05-19  ...                     NaN
# 4                     722.0    Medium 2009-07-23  ...                     NaN
#
# ...

# %%
fig, ax = plt.subplots()

ax .scatter(df["saledate"][:1000], df["SalePrice"][:1000])

# %%
df.head().T
# Out:
#                                                                  0  \
# SalesID                                                    1139246
# SalePrice                                                  66000.0
# MachineID                                                   999089
# ModelID                                                       3157
# datasource                                                     121
# auctioneerID                                                   3.0
# YearMade                                                      2004
# MachineHoursCurrentMeter                                      68.0
# UsageBand                                                      Low
# saledate                                       2006-11-16 00:00:00
# fiModelDesc                                                   521D
# fiBaseModel                                                    521
# fiSecondaryDesc                                                  D
# ...

# %%
df.saledate.head()
# Out:
# 0   2006-11-16
# 1   2004-03-26
# 2   2004-02-26
# 3   2011-05-19
# 4   2009-07-23
# Name: saledate, dtype: datetime64[us]

# %%
df.sort_values(inplace=True,ascending=True, by = ["saledate"])

df.saledate.head()
# Out:
# 205615   1989-01-17
# 274835   1989-01-31
# 141296   1989-01-31
# 212552   1989-01-31
# 62755    1989-01-31
# Name: saledate, dtype: datetime64[us]

# %%
# Make a copy of the original DataFrame

df_sorted_date = df.copy()

df_sorted_date
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 205615  1646770     9500.0    1126363     8434         132          18.0
# 274835  1821514    14000.0    1194089    10150         132          99.0
# 141296  1505138    50000.0    1473654     4139         132          99.0
# 212552  1671174    16000.0    1327630     8591         132          99.0
# 62755   1329056    22000.0    1336053     4089         132          99.0
# ...         ...        ...        ...      ...         ...           ...
# 410879  6302984    16000.0    1915521     5266         149          99.0
# 412476  6324811     6000.0    1919104    19330         149          99.0
# 411927  6313029    16000.0    1918416    17244         149          99.0
# 407124  6266251    55000.0     509560     3357         149          99.0
# 409203  6283635    34000.0    1869284     4701         149          99.0
#
#         YearMade  MachineHoursCurrentMeter UsageBand   saledate  ...  \
# ...

# %%
df_sorted_date.saledate.head()
# Out:
# 205615   1989-01-17
# 274835   1989-01-31
# 141296   1989-01-31
# 212552   1989-01-31
# 62755    1989-01-31
# Name: saledate, dtype: datetime64[us]

# %% [markdown]
# ## Minor feature Engineenging done to the sale date
#
# - Added the following features
#   * Sale Year
#   * Sale Month
#   * Sale date of Year
# - Removed
#   * Sale date (**Note - Can always be recovered from original data**)

# %%
df_sorted_date.head()
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 205615  1646770     9500.0    1126363     8434         132          18.0
# 274835  1821514    14000.0    1194089    10150         132          99.0
# 141296  1505138    50000.0    1473654     4139         132          99.0
# 212552  1671174    16000.0    1327630     8591         132          99.0
# 62755   1329056    22000.0    1336053     4089         132          99.0
#
#         YearMade  MachineHoursCurrentMeter UsageBand   saledate  ...  \
# 205615      1974                       NaN       NaN 1989-01-17  ...
# 274835      1980                       NaN       NaN 1989-01-31  ...
# 141296      1978                       NaN       NaN 1989-01-31  ...
# 212552      1980                       NaN       NaN 1989-01-31  ...
# 62755       1984                       NaN       NaN 1989-01-31  ...
#
#        Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer  \
# ...

# %% [markdown]
# ### 5. Model driven EDA

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_jobs=-1, random_state=42)

model.fit(df_sorted_date.drop("SalePrice", axis=1), df_sorted_date["SalePrice"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_844268/1957838911.py in ?()
#       1 from sklearn.ensemble import RandomForestRegressor
#       2
#       3 model = RandomForestRegressor(n_jobs=-1, random_state=42)
#       4
# ----> 5 model.fit(df_sorted_date.drop("SalePrice", axis=1), df_sorted_date["SalePrice"])
#
# ~/Desktop/bulldozer_sales/env/lib/python3.14/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1332                 skip_parameter_validation=(
#    1333                     prefer_skip_nested_validation or global_skip_validation
#    1334                 )
#    1335             ):
# -> 1336                 return fit_method(estimator, *args, **kwargs)
#
# ~/Desktop/bulldozer_sales/env/lib/python3.14/site-packages/sklearn/ensemble/_forest.py in ?(self, X, y, sample_weight)
#     355         # Validate or convert input data
# ...

# %%
df_sorted_date.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 412698 entries, 205615 to 409203
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   str
#  9   saledate                  412698 non-null  datetime64[us]
#  10  fiModelDesc               412698 non-null  str
#  11  fiBaseModel               412698 non-null  str
#  12  fiSecondaryDesc           271971 non-null  str
# ...

# %% [markdown]
# ### Convert strings to categories using pandas

# %%
# Find columns that contains strings

for label , content in df_sorted_date.items():
    if pd.api.types.is_string_dtype(content):
        print(label)
# Out:
# UsageBand
# fiModelDesc
# fiBaseModel
# fiSecondaryDesc
# fiModelDescriptor
# ProductSize
# fiProductClassDesc
# state
# ProductGroup
# ProductGroupDesc
# Drive_System
# Enclosure
# Forks
# Pad_Type
# Ride_Control
# Stick
# Transmission
# Turbocharged
# Blade_Extension
# Blade_Width
# Enclosure_Type
# Engine_Horsepower
# Hydraulics
# Pushblock
# Ripper
# Scarifier
# Tip_Control
# Tire_Size
# Coupler
# Coupler_System
# Grouser_Tracks
# Hydraulics_Flow
# Track_Type
# Undercarriage_Pad_Width
# Stick_Length
# Thumb
# Pattern_Changer
# Grouser_Type
# Backhoe_Mounting
# Blade_Type
# Travel_Controls
# Differential_Type
# Steering_Controls

# %%
df_sorted_date.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 412698 entries, 205615 to 409203
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   str
#  9   saledate                  412698 non-null  datetime64[us]
#  10  fiModelDesc               412698 non-null  str
#  11  fiBaseModel               412698 non-null  str
#  12  fiSecondaryDesc           271971 non-null  str
# ...

# %%
# Turn all string values into category values

for label, content in df_sorted_date.items():
    if pd.api.types.is_string_dtype(content):
        df_sorted_date[label] = content.astype("category").cat.as_ordered()

# %%
df_sorted_date.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 412698 entries, 205615 to 409203
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   category
#  9   saledate                  412698 non-null  datetime64[us]
#  10  fiModelDesc               412698 non-null  category
#  11  fiBaseModel               412698 non-null  category
#  12  fiSecondaryDesc           271971 non-null  category
# ...

# %%
df_sorted_date.state.cat.codes
# Out:
# 205615    43
# 274835     8
# 141296     8
# 212552     8
# 62755      8
#           ..
# 410879     4
# 412476     4
# 411927     4
# 407124     4
# 409203     4
# Length: 412698, dtype: int8

# %%
# Checking the missing numbers

(df_sorted_date.isnull().sum()/ len(df_sorted_date))*100
# Out:
# SalesID                      0.000000
# SalePrice                    0.000000
# MachineID                    0.000000
# ModelID                      0.000000
# datasource                   0.000000
# auctioneerID                 4.879113
# YearMade                     0.000000
# MachineHoursCurrentMeter    64.258610
# UsageBand                   82.149174
# saledate                     0.000000
# fiModelDesc                  0.000000
# fiBaseModel                  0.000000
# fiSecondaryDesc             34.099269
# fiModelSeries               85.784520
# fiModelDescriptor           81.871490
# ProductSize                 52.485110
# fiProductClassDesc           0.000000
# state                        0.000000
# ProductGroup                 0.000000
# ProductGroupDesc             0.000000
# Drive_System                74.051970
# Enclosure                    0.080931
# Forks                       52.092087
# Pad_Type                    80.349796
# Ride_Control                62.992794
# ...

# %% [markdown]
# ## Save preprocessed data

# %%
#Export current temporary data

df_sorted_date.to_csv("data/bluebook-for-bulldozers/train_temp.csv", index= False)

# %%
# Import preprocessing data

df_sorted_date = pd.read_csv("data/bluebook-for-bulldozers/train_temp.csv", low_memory = False)

df_sorted_date.head(). T
# Out:
#                                                                           0  \
# SalesID                                                             1646770
# SalePrice                                                            9500.0
# MachineID                                                           1126363
# ModelID                                                                8434
# datasource                                                              132
# auctioneerID                                                           18.0
# YearMade                                                               1974
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# saledate                                                         1989-01-17
# fiModelDesc                                                            TD20
# ...

# %%
((df_sorted_date.isnull().sum())/len(df_sorted_date)) * 100
# Out:
# SalesID                      0.000000
# SalePrice                    0.000000
# MachineID                    0.000000
# ModelID                      0.000000
# datasource                   0.000000
# auctioneerID                 4.879113
# YearMade                     0.000000
# MachineHoursCurrentMeter    64.258610
# UsageBand                   82.149174
# saledate                     0.000000
# fiModelDesc                  0.000000
# fiBaseModel                  0.000000
# fiSecondaryDesc             34.099269
# fiModelSeries               85.784520
# fiModelDescriptor           81.871490
# ProductSize                 52.485110
# fiProductClassDesc           0.000000
# state                        0.000000
# ProductGroup                 0.000000
# ProductGroupDesc             0.000000
# Drive_System                74.051970
# Enclosure                    0.080931
# Forks                       52.092087
# Pad_Type                    80.349796
# Ride_Control                62.992794
# ...

# %% [markdown]
# ### Filling the missing values
#
# #### 1. Filling numeric value first

# %%
for label, content in df_sorted_date.items():
    if pd.api.types.is_numeric_dtype(content):
        print(label)
# Out:
# SalesID
# SalePrice
# MachineID
# ModelID
# datasource
# auctioneerID
# YearMade
# MachineHoursCurrentMeter

# %%
# Check which have null values

for label, content in df_sorted_date.items():
    if pd.api.types.is_numeric_dtype(content) and pd.isnull(content).sum():
        print(label)
# Out:
# auctioneerID
# MachineHoursCurrentMeter

# %%
# FIll numeric rows with median

for label, content in df_sorted_date.items():
    if pd.api.types.is_numeric_dtype(content) and pd.isnull(content).sum():
        # Add a binary column that shows if the row was missing the data
        df_sorted_date[label + "_is_missing"] = pd.isnull(content)

        df_sorted_date[label] = content.fillna(content.median()) # median more robust with outliers

# %%
for label, content in df_sorted_date.items():
    if pd.api.types.is_numeric_dtype(content) and pd.isnull(content).sum():
        print(label)

# %%
# Check the sum of missing data in columns

df_sorted_date.auctioneerID_is_missing.value_counts()
# Out:
# auctioneerID_is_missing
# False    392562
# True      20136
# Name: count, dtype: int64

# %%
df_sorted_date.MachineHoursCurrentMeter_is_missing.value_counts()
# Out:
# MachineHoursCurrentMeter_is_missing
# True     265194
# False    147504
# Name: count, dtype: int64

# %%
df_sorted_date.isna().sum()
# Out:
# SalesID                                     0
# SalePrice                                   0
# MachineID                                   0
# ModelID                                     0
# datasource                                  0
# auctioneerID                                0
# YearMade                                    0
# MachineHoursCurrentMeter                    0
# UsageBand                              339028
# saledate                                    0
# fiModelDesc                                 0
# fiBaseModel                                 0
# fiSecondaryDesc                        140727
# fiModelSeries                          354031
# fiModelDescriptor                      337882
# ProductSize                            216605
# fiProductClassDesc                          0
# state                                       0
# ProductGroup                                0
# ProductGroupDesc                            0
# ...
